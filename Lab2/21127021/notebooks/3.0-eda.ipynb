# %% [markdown]
# <div style="text-align: center; background-color: #559cff; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 20px; font-size: 40px; font-weight: bold; border-radius: 0 0 0 0; box-shadow: 0px 6px 8px rgba(0, 0, 0, 0.2);">
#   Lab 02 - Introduction To Data Science @ FIT-HCMUS, VNU-HCM 📌
# </div>

# %% [markdown]
# <div style="text-align: center; background-color: #b1d1ff; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 20px; font-size: 40px; font-weight: bold; border-radius: 0 0 0 0; box-shadow: 0px 6px 8px rgba(0, 0, 0, 0.2);">
#   Stage 3.0 - Exploratory data analysis
# </div>

# %% [markdown]
# ## Import

# %%
import os
import sys

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# YOUR CODE HERE (OPTION) 
# If you need other libraries, you can import them here
import seaborn as sns

# %% [markdown]
# ## Exploring your data

# %% [markdown]
# ### Read cleaned data from file (0.25 points)

# %% [markdown]
# We can now use the cleaned dataset for analysis. Thus, we first read the CSV files we created in the previous pre-processing task.

# %%
# YOUR CODE HERE
cleaned_df = pd.read_csv("../data/processed/21127021_europe_processed.csv")

# %%
# TEST
cleaned_df.head()
# Out:
#    Total Population  Female Population  Male Population  Birth Rate  \
# 0         2775634.0          1391086.0        1384548.0   10.813117
# 1         2811666.0          1407212.0        1404454.0   10.240000
# 2         2837849.0          1418585.0        1419264.0   10.285000
# 3         2854191.0          1425363.0        1428828.0   10.343000
# 4         2866376.0          1430495.0        1435881.0   10.517000
#
#    Death Rate  Compulsory Education Dur.  Employment in Industry(%)  \
# 0   10.096538                        9.0                  26.361868
# 1   11.325000                        9.0                  21.562780
# 2   10.785000                        9.0                  20.781540
# 3    8.480000                        9.0                  20.150670
# 4    8.308000                        9.0                  19.745660
#
#    Employment in Agriculture(%)  Female Employment in Agriculture(%)  \
# 0                      9.386339                             8.456056
# ...

# %%
# TEST
cleaned_df.shape
# Out:
# (1120, 25)

# %% [markdown]
# ### Numerical analysis using descriptive statistics (0.25 points)

# %% [markdown]
# Descriptive statistics show the characteristics of numerical features. It shows us the information such as:
# - The mean (and you can go further with advanced techiques as Arithmetic mean, Geometric mean, Harmonic mean)
# - The median
# - The mode
# - Quantiles (Quartiles, Percentiles, Deciles, Crocodiles?)
# - Range and IQR (Interquartile Range) (you might find that its relation to box plots)
# - Variance and Standard deviation (std dev)
# - Coefficient of Variation
# - Skewness
# - Kurtosis
# - Standard Error (of the sample mean)
# - Moments
# - Covariance and Correlation
#
# Due the scope of this lab, you just need to use basic function of Pandas to calculate basic descriptive statistics information and give insights from it.

# %%
df_copy = cleaned_df.drop(['Year', 'Country'], axis='columns')

# YOUR CODE HERE
df_copy.describe()
# Out:
#        Total Population  Female Population  Male Population   Birth Rate  \
# count      1.120000e+03       1.120000e+03     1.120000e+03  1120.000000
# mean       1.399210e+07       7.200463e+06     6.791642e+06    10.813117
# std        2.085705e+07       1.072965e+07     1.013146e+07     1.913733
# min        2.488600e+04       1.277900e+04     1.210700e+04     5.900000
# 25%        2.019648e+06       1.025421e+06     9.939572e+05     9.500000
# 50%        5.376422e+06       2.743866e+06     2.625598e+06    10.699000
# 75%        1.053030e+07       5.424500e+06     5.169164e+06    11.700000
# max        8.407981e+07       4.259320e+07     4.148661e+07    25.000000
#
#         Death Rate  Compulsory Education Dur.  Employment in Industry(%)  \
# count  1120.000000                1120.000000                1120.000000
# mean     10.096538                  10.231975                  26.361868
# std       2.409081                   1.272694                   6.026379
# ...

# %% [markdown]
# **TODO**: Give your obervation here
# Các con số thống kê cơ bản cho ta một cái nhìn khái quát về dữ liệu.
# - count: Cho ta biết số lượng mẫu trong tập dữ liệu, cụ thể hơn trong trường hợp với dữ liệu bên trên ta có thể kết luận được rằng không có sự mất mát dữ liệu vì giá trị count ở các cột bằng chính số hàng của tập dữ liệu (1200 hàng).
# - mean: Cho ta biết được sự phân bố và tập trung của dữ liệu, dữ liệu có xu hướng tập trung tại giá trị nào.
# - std: Cho ta biết biến động của dữ liệu so với giá trị trung bình. Trong tập dữ liệu này ta có thể quan sát được độ lệch chuẩn tỉ lệ thuận với miền giá trị (min - max).
# - min, max: Cho ta biết miền phân bổ của dữ liệu
# - Quartiles (25%, 50%, 75%): Cho ta biết dữ liệu có được phân bổ đều hay không, tứ phân vị còn có thể cho ta biết trong trường hợp dữ liệu bị lệch ta có thể kết luận rõ hơn là dữ liệu đang lệch trái hay lệch phải và đưa ra các phương án chuẩn hóa dữ liệu hiệu quả trong tương lai.
#
# Ta có thể thấy rõ hơn trong tập dữ liệu phía trên, giá trị phân vị 50% của 3 thuộc tính population, female population và male population không gần với giá trị của mean do đó ta có thể kết luận rằng 3 cột này có miền phân bổ giá trị bị lệch. Hơn thế nữa giá trị phân vị 50% ở 3 thuộc tính trên còn bé hơn giá trị mean nên ta có thể kết luận rằng dữ liệu 3 thuộc tính trên bị lệch phải.

# %% [markdown]
# ### Describe the correlation between features in the dataset (0.75 points)

# %% [markdown]
# Considering the available features within the training dataset, we want to identify and analyse the relationships between them, and then determine which features within the dataset significantly contribute to our solution goal. By using calculation and visualisation, Python allows us to create a correlation matrix, which is a table that represents the correlation coefficients between different variables.

# %% [markdown]
# Now let's make a correlation matrix, then visualize it, and describe what insights you observed?

# %%
# PRE-PROCESSING IF NEEDED
# YOUR CODE HERE (OPTION)

# %%
# YOUR CODE HERE
# create a copy
df_copy = cleaned_df.copy()

# Exclude the categorical features from the matrix
df_copy.drop(['Year', 'Country'], inplace=True, axis='columns')

# plot a correlation matrix
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(df_copy.corr(), cmap='RdBu', center=0,ax=ax)
plt.show()

# %% [markdown]
# **Question 01**: How does the correlation between features change in the top 10 countries with the LARGEST population?
#
# When we have an answer for this question, we might see how features interaction with each other when the conutry population is large.

# %%
# PRE-PROCESSING IF NEEDED
# YOUR CODE HERE (OPTION)

# %%
# YOUR CODE HERE
# select top 10 countries with the largest population
df_copy = cleaned_df.copy()

top_countries_largest = df_copy.groupby("Country").mean('Total Population').sort_values("Total Population", ascending = False).head(10)
top_countries_largest.reset_index(drop = True, inplace =True)
top_countries_largest.drop(['Year'], axis = 'columns')

top_countries_largest
# Out:
#    Total Population  Female Population  Male Population  Birth Rate  \
# 0      8.215120e+07       4.195401e+07     4.019720e+07    9.011183
# 1      6.411858e+07       3.306710e+07     3.105147e+07   12.382611
# 2      6.232010e+07       3.176091e+07     3.055919e+07   11.875468
# 3      5.862630e+07       3.019945e+07     2.842684e+07    8.900468
# 4      4.660210e+07       2.505422e+07     2.154788e+07    9.432611
# 5      4.438858e+07       2.257312e+07     2.181546e+07    9.507611
# 6      3.815435e+07       1.965999e+07     1.849436e+07   10.071897
# 7      1.653069e+07       8.342250e+06     8.188440e+06   11.221897
# 8      1.085178e+07       5.486885e+06     5.364894e+06    9.307611
# 9      1.081564e+07       5.508573e+06     5.307063e+06   11.146897
#
#    Death Rate  Compulsory Education Dur.  Employment in Industry(%)  \
# 0   10.674876                  12.703426                  30.071868
# 1    8.892733                  10.346283                  23.249071
# ...

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(top_countries_largest.corr(), cmap='RdBu', center=0,ax=ax)
plt.show()

# %% [markdown]
# **YOUR ANSWER**
#
# Đối với top 10 quốc gia có dân số lớn nhất, ta thấy rằng mức độ tương quan của các giá trị tăng lên (cả tương quan nghịch và tương quan thuận). Điển hình như tương quan giữa thuộc tính "Male life expectancy" so với "Employment in Agriculture" sẽ tương quan mạnh hơn so với ban đầu. Sự thay đổi rõ rệt nhất nằm ở sự tương quan giữa "School enrollment, teritary" với "Total Population" có sự thay đổi từ tương quan nghịch yếu chuyển sang tương quan nghịch mạnh (có ý nghĩa nếu dân số đông sẽ kéo theo việc tỉ lệ nhập học đại học sẽ giảm). </br>
# Nhìn chung các sự tương quan có tính tăng lên về cường độ so với xét trên toàn bộ tập dữ liệu. </br>
# Có thể kết luận rằng chúng ta có thể lượt bỏ bớt các thuộc tính tương quan mạnh với thuộc tính khác mà không làm ảnh hưởng đến các phân tích và mô hình sau này bỏi lẽ nếu 2 thuộc tính tương quan mạnh với nhau có nghĩa là ta có thể suy ra được giá trị của thuộc tính này nhờ thuộc tính kia và giữ lại cả 2 thuộc tính có thể làm lãng phí và dư thừa.
#
# - Mối tương quan thuận: Ta có thể thấy trong biểu đồ heatmap, các thuộc tính có sự tương quan thuận với nhau như Total Population với Male Population và Female Population. Employment in Agriculture(%) với Female Employment in Agriculture(%), Male life expectancy với Female life expectancy. Các thuộc tính này có xu hướng suy ra lẫn nhau tức là khi một thuộc tính tăng thì thuộc tính kia sẽ tăng theo. Mỗi tương quan thuận nhưng giá trị ít hơn như các mối tương quan giữa Total Population với GDP in USD cũng có ý nghĩa tương tự nhưng sẽ yếu hơn các thuộc tính có mức tương quan mạnh hơn.
# - Mối tương quan nghịch: Trong biểu đồ trên ta có thể chỉ ra một vài mối tương quan nghịch tiêu biểu như Death Rate với Male life expectancy và Female life expectancy, Net income from Abroad với Male life expectancy và Female life expectancy, Electric Power Consumption(kWH per capita) với Employment in Agriculture(%) và Female Employment in Agriculture(%). Mối tương quan này có ý nghĩa khi một thuộc tính này tăng thì thuộc tính kia sẽ giảm.
# Chúng ta có thể lượt bỏ bớt những thuộc tính có mối tương quan mạnh với nhau (cả thuận và nghịc) mà không làm ảnh hưởng tới kết quả phân tích và các mô hình học máy sau này. Bỏi lẽ khi 2 thuộc tính tương quan mạnh với nhau thì có thể suy ra lẫn nhau và điều này dẫn đến sự dư thừa.

# %% [markdown]
# **Question 02**: How does the correlation between features change in the top 10 countries with the SMALLEST population?
#
# When we have an answer for this question, we might see how features interaction with each other when the conutry population is small.

# %%
# PRE-PROCESSING IF NEEDED
# YOUR CODE HERE (OPTION)

# %%
# YOUR CODE HERE
df_copy = cleaned_df.copy()

top_countries_smallest = df_copy.groupby("Country").mean('Total Population').sort_values("Total Population", ascending = True).head(10)
top_countries_smallest.reset_index(drop = True, inplace =True)
top_countries_smallest.drop(['Year'], axis = 'columns')

top_countries_smallest
# Out:
#    Total Population  Female Population  Male Population  Birth Rate  \
# 0      3.032704e+04       1.517686e+04     1.515018e+04   12.442183
# 1      3.052329e+04       1.563193e+04     1.489136e+04    9.493970
# 2      3.393679e+04       1.737836e+04     1.655843e+04   10.939815
# 3      3.543125e+04       1.791057e+04     1.752068e+04   10.757611
# 4      4.821632e+04       2.324546e+04     2.497086e+04   13.636183
# 5      3.141060e+05       1.555194e+05     1.585866e+05   13.993326
# 6      4.269768e+05       2.123279e+05     2.146489e+05   10.121897
# 7      5.103039e+05       2.561903e+05     2.541136e+05   11.557611
# 8      1.352021e+06       7.200910e+05     6.319299e+05   10.311183
# 9      2.033601e+06       1.031580e+06     1.002021e+06    9.639754
#
#    Death Rate  Compulsory Education Dur.  Employment in Industry(%)  \
# 0    7.894805                  10.096283                  26.361868
# 1    8.334478                  10.024854                  26.361868
# ...

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(top_countries_smallest.corr(), cmap='RdBu', center=0,ax=ax)
plt.show()

# %% [markdown]
# **YOUR ANSWER**
#
# Example: Is that possible to drop any features that have less effect?
#
# Đối với top 10 quốc gia có dân số thấp nhất, ta có thể thấy sự thay đổi lớn nhất về mặt tương quan nằm ở thuộc tính Total Population, Male Population và Female Population so với các thuộc tính còn lại. Các tương quan nghịch tập trung vào trung tâm biểu đồ heatmap nhiều hơn so với biểu đồ biểu diễn toàn bộ dữ liệu. Giá trị của các sự tương quan cũng lớn hơn so với biểu đồ ban đầu.
# - Tương quan thuận: Giống như top 10 quốc gia có dân số đông nhất, sự tương quan thuận của top 10 quốc gia có dân số bé nhất chủ yếu tập trung vào các thuộc tính Total Population với Male Population và Female Population, Employment in Industry(%) với Female Employment in Industry(%), Employment in Agriculture(%) với Female Employment in Agriculture(%), Male life expectancy với Female life expectancy.
# - Tương quan nghịch: Sự tương quan nghịch rõ nét nhất nằm ở thuộc tính Death Rate với Male life expectancy và Female life expectancy, các tương quan nghịch nhỏ hơn có thể kể đến như Compulsory Education Dur với Employment in Industry(%), Fossil Fuel Consumption (%) với Renewable Energy Consumption (%).
# Chúng ta có thể bỏ các thuộc tính như Male Population, Female Population, Male life expectancy và Female life expectancy mà gây ít tác động đến ý nghĩa của toàn bộ dữ liệu bỏi lẽ những thuộc tính này có sự tương quan cao nhất trong tập dữ liệu.

# %% [markdown]
# ## Making a question? (1.25 points)

# %% [markdown]
# After exploring the data, we have a better understanding of the data. Now let's see what questions can be answered with this data.
#
# **A possible question is:** What is the population situation of the countries on the continent today?
#
# **Answering this question will** help us to see the current population status and predictions about the future development of the labor force of the countries on the continent are under consideration.
#
# **How we answer this question**: we will consider the Average Birth Rate and Death Rate for countries across all the year.

# %% [markdown]
# ### Pre-processing

# %% [markdown]
# ### Analyzing to get the answer

# %% [markdown]
# Step 01: construct Average Birth Rate dataframe for each country.

# %%
# Create a new dataframe
avg_birthrate_df = pd.DataFrame()

# YOUR CODE HERE

# Find average for each country
avg_birthrate_df["Avg.Birth Rate"] = cleaned_df.groupby("Country")["Birth Rate"].mean()

# Set the index as a column - countries
avg_birthrate_df["Country"] = avg_birthrate_df.index

# Drop the index
avg_birthrate_df.reset_index(drop=True, inplace=True)

# Sort the rows based of Average Birth Rate
avg_birthrate_df.sort_values("Avg.Birth Rate", inplace=True, ascending=False)

# Display
avg_birthrate_df.head()
# Out:
#     Avg.Birth Rate        Country
# 18       14.346897        Ireland
# 17       13.993326        Iceland
# 0        13.738611        Albania
# 10       13.636183  Faroe Islands
# 26       13.045790        Moldova

# %%
# Plotting for top countries
# YOUR CODE HERE
plt.figure(figsize=(8, 5))
sns.set(style="whitegrid")
ax = sns.barplot(data=avg_birthrate_df.head(), x="Country", y= "Avg.Birth Rate")

# %% [markdown]
# Step 02: construct Average Death Rate dataframe for each country.

# %%
# Create a new dataframe
avg_deathrate_df = pd.DataFrame()

# YOUR CODE HERE

# Find average for each country
avg_deathrate_df ["Avg.Death Rate"] = cleaned_df.groupby("Country")["Death Rate"].mean()

# Set the index as a column - countries
avg_deathrate_df["Country"] = avg_deathrate_df .index

# Drop the index
avg_deathrate_df .reset_index(drop=True, inplace=True)

# Sort the rows based of Average Birth Rate
avg_deathrate_df .sort_values("Avg.Death Rate", inplace=True, ascending=False)

# Display
avg_deathrate_df .head()
# Out:
#     Avg.Death Rate   Country
# 38       15.199876   Ukraine
# 5        14.860591  Bulgaria
# 20       14.371305    Latvia
# 2        13.703341   Belarus
# 16       13.310591   Hungary

# %%
# Plotting for top countries
# YOUR CODE HERE
plt.figure(figsize=(8, 5))
sns.set(style="whitegrid")
ax = sns.barplot(data=avg_deathrate_df.head(), x="Country", y= "Avg.Death Rate")

# %% [markdown]
# **TODO**: Give your obervation here
#
# - Ta có thể thấy từ 2 dữ liệu trung bình tỉ lệ sinh và tỉ lệ chết phía trên có thể kết luận rằng tỉ lệ chết đang cao hơn so với tỉ lệ sinh. Đặc biệt với nước Ukraine với tỉ lệ chết đứng đầu nhưng tỉ lệ sinh không nằm trong top 5 và xu hướng chung của dân số châu Âu đang bị tụt giảm.
# - Có một vài trường hợp đặc biệt như các nước Ireland và Iceland có tỉ lệ sinh cao hơn tỉ lệ chết và dân số có xư hướng tăng.
# - Một trường hợp khác nằm ở nước Latvia khi nước này đều xếp thứ 3 trong cả tỉ lệ sinh và chết và ta có thể thấy được tỉ lệ chết ở nước này đang cao hơn tỉ lệ sinh vì thế nước này có xu hướng dân số sẽ bị giảm sút trong tương lai

# %% [markdown]
# ## Making your own question 01? (1.5 points)

# %% [markdown]
# **YOUR ANSWER HERE** <br>
# - Tình hình phân bổ giới tính ở các nước châu Âu hiện nay như thế nào? <br>
# - Trả lời câu hỏi này có thể giúp chúng ta hiểu rõ hơn về tình hình cân bằng giới tính hiện nay của các nước châu Âu và đưa ra dự đoán về tương lai. <br>
# - Để trả lời câu hỏi này ta sẽ tập trung phân tích vào tỉ lệ nam/nữ ở các nước và đối chiếu với tuổi thọ của từng giới.

# %% [markdown]
# ### Pre-processing

# %%
# YOUR CODE HERE (OPTION)

# %% [markdown]
# ### Analyzing to get the answer

# %%
# YOUR CODE HERE
avg_male_df = pd.DataFrame()

avg_male_df["Avg.Male Population"] = cleaned_df.groupby("Country")["Male Population"].mean()

avg_male_df["Country"] = avg_male_df.index
avg_male_df.reset_index(drop=True, inplace=True)
avg_male_df.sort_values("Avg.Male Population", inplace=True, ascending=False)

avg_male_df.head()
# Out:
#     Avg.Male Population         Country
# 13         4.019720e+07         Germany
# 12         3.105147e+07          France
# 39         3.055919e+07  United Kingdom
# 19         2.842684e+07           Italy
# 35         2.181546e+07           Spain

# %%
plt.figure(figsize=(8, 5))
sns.set_style("whitegrid")
ax = sns.barplot(data=avg_male_df.head(), x="Country", y="Avg.Male Population")

# %%
avg_female_df = pd.DataFrame()

avg_female_df["Avg.Female Population"] = cleaned_df.groupby("Country")["Female Population"].mean()

avg_female_df["Country"] = avg_female_df.index
avg_female_df.reset_index(drop=True, inplace=True)
avg_female_df.sort_values("Avg.Female Population", inplace=True, ascending=False)

avg_female_df.head()
# Out:
#     Avg.Female Population         Country
# 13           4.195401e+07         Germany
# 12           3.306710e+07          France
# 39           3.176091e+07  United Kingdom
# 19           3.019945e+07           Italy
# 38           2.505422e+07         Ukraine

# %%
plt.figure(figsize=(8, 5))
sns.set_style("whitegrid")
ax = sns.barplot(data=avg_female_df.head(), x="Country", y="Avg.Female Population")

# %%
population = pd.merge(avg_male_df, avg_female_df, on="Country")
population['ratio'] = population["Avg.Male Population"] / population["Avg.Female Population"]
population.sort_values("ratio", inplace=True, ascending=False)
population.head()
# Out:
#     Avg.Male Population         Country  Avg.Female Population     ratio
# 35         2.497086e+04   Faroe Islands           2.324546e+04  1.074225
# 34         1.585866e+05         Iceland           1.555194e+05  1.019722
# 33         2.146489e+05           Malta           2.123279e+05  1.010931
# 28         1.023576e+06  Macedonia, FYR           1.020359e+06  1.003153
# 38         1.515018e+04       Gibraltar           1.517686e+04  0.998242

# %%
fig = plt.figure(figsize=(7, 7))
plt.title("Boxplot ratio between Male population and Female population")
plt.boxplot(x = population['ratio'])
plt.show()

# %% [markdown]
# **Nhận xét** </br>
# Đa phần tỉ lệ nam/nữ ở các nước châu Âu có xu hướng nhỏ hơn 1. Tức là nam < nữ và điều này gây ra sự mất cân bằng giới tính cho các nước châu Âu trong hiện tại. Để dự đoán sự cân bằng giới tính trong tương lai ta sẽ xét thêm tuổi thọ trung bình giữa nam và nữ ở châu Âu.

# %%
avg_male_life_expectancy = cleaned_df['Male life expectancy'].mean()
avg_female_life_expectancy = cleaned_df['Female life expectancy '].mean()
plt.bar(x = ["Avg Male life expectancy", "Avg Female life expectancy"], height=[avg_male_life_expectancy, avg_female_life_expectancy])
plt.show()

# %% [markdown]
# **Nhận xét**<br>
# Ta đã rút ra được kết luận dân số nữ đang nhiều hơn dân số nam ở châu Âu, cộng với việc tuổi thọ Nam lại ngắn hơn nữ nên ta có thể nói rằng châu Âu đang có sự mất cân bằng giới tính và điều này có thể tiếp diễn trong tương lai gần.

# %% [markdown]
# ## Making your own question 02? (1.5 points)

# %% [markdown]
# **YOUR ANSWER HERE** <br>
# - Xu hướng phân bổ nhân lực các ngành trong nền kinh tế của châu Âu biến đổi như thế nào qua các năm? <br>
# - Trả lời câu hỏi này giúp chúng ta nhìn nhận ra tỉ trọng việc làm được tạo ra qua các năm tại châu Âu<br>
# - Để trả lời câu hỏi này ta sẽ đi phân tích sự dịch chuyển của nguồn nhân lực 2 nhóm ngành chính là công nghiệp và nông nghiệp qua từng năm của toàn bộ châu Âu.

# %% [markdown]
# ### Pre-processing

# %%
# YOUR CODE HERE (OPTION)

# %% [markdown]
# ### Analyzing to get the answer

# %%
# YOUR CODE HERE
avg_agriculture_year = pd.DataFrame()
avg_agriculture_year['Avg.Employment in Agriculture per Year'] = cleaned_df.groupby('Year')['Employment in Agriculture(%)'].mean()
avg_agriculture_year['Year'] = avg_agriculture_year.index
avg_agriculture_year.reset_index(inplace=True, drop=True)
avg_agriculture_year.head(5)
# Out:
#    Avg.Employment in Agriculture per Year  Year
# 0                               12.744480  1995
# 1                               12.495269  1996
# 2                               12.226384  1997
# 3                               11.988248  1998
# 4                               11.732194  1999

# %%
avg_industry_year = pd.DataFrame()
avg_industry_year["Avg.Employment in Industry per Year"] = cleaned_df.groupby('Year')['Employment in Industry(%)'].mean()
avg_industry_year['Year'] = avg_industry_year.index
avg_industry_year.reset_index(inplace=True, drop=True)
avg_industry_year.head()
# Out:
#    Avg.Employment in Industry per Year  Year
# 0                            29.410572  1995
# 1                            28.945545  1996
# 2                            28.790306  1997
# 3                            28.883434  1998
# 4                            28.308226  1999

# %%
fig, ax = plt.subplots(figsize=(7, 7))
sns.set(style="whitegrid")
plt.title('Biểu đồ biểu diễn tỉ lệ nhân lực các nhóm ngành qua từng năm')
plt.xlabel("Năm")
plt.ylabel("Tỉ lệ(%)")
agriculture, = ax.plot(avg_agriculture_year['Year'], avg_agriculture_year['Avg.Employment in Agriculture per Year'], '-')
industry, = ax.plot(avg_industry_year['Year'], avg_industry_year['Avg.Employment in Industry per Year'], '-')
ax.legend([agriculture, industry], ['Nông nghiệp', "Công nghiệp"], title = "Legend")
plt.show()

# %% [markdown]
# ## Nhận xét
# Ta có thể thấy rằng tỉ lệ việc làm công và nông nghiệp giảm dần qua từng năm. Có một số sự khác biệt khi tỉ lệ việc làm ngành công nghiệp có xu hướng đi ngang trong giai đoạn 2013 đến 2021 và tăng tại năm 2022. Trong khi đó tỉ lệ việc làm ngành nông nghiệp lại giảm dần và chỉ có dấu hiệu tăng bất thường tại năm 2022. Tình hình chung trong tương lai tỉ lệ việc làm của nhóm ngành công nghiệp có thể giữ nguyên hoặc giảm nhẹ trong khi nông nghiệp có xu hướng giảm nhiều hơn.

# %% [markdown]
# # Question 3 <br>
# - Tỉ lệ sử dụng nhân lực nữ giới trong nông nghiệp so với công nghiệp công nghiệp qua các năm ở châu Âu<br>
# - Trả lời câu hỏi này ta sẽ rút ra được cái nhìn tổng thể về nguồn nhân lực là nữ giới trong quá trình phát triển kinh tế của châu Âu qua các năm và đưa ra dự đoán về tương lai. <br>
# - Để trả lời câu hỏi này ta sẽ phân tích sự biến đổi của tỉ lệ nữ trong nông, công nghiệp qua các năm

# %% [markdown]
# ### Analyzing to get the answer

# %%
avg_agriculture = pd.DataFrame()
avg_agriculture['value'] = cleaned_df.groupby('Year')['Female Employment in Agriculture(%)'].mean()
avg_agriculture['Year'] = avg_agriculture.index
avg_agriculture.reset_index(inplace=True, drop=True)
avg_agriculture.head()
# Out:
#        value  Year
# 0  11.942170  1995
# 1  11.658717  1996
# 2  11.384004  1997
# 3  11.167282  1998
# 4  10.920880  1999

# %%
avg_industry = pd.DataFrame()
avg_industry['value'] = cleaned_df.groupby("Year")["Female Employment in Industry(%)"].mean()
avg_industry['Year'] = avg_industry.index
avg_industry.reset_index(inplace=True, drop=True)
avg_industry.head()
# Out:
#        value  Year
# 0  19.007435  1995
# 1  18.569609  1996
# 2  18.204333  1997
# 3  18.215133  1998
# 4  17.604182  1999

# %%
fig, ax = plt.subplots(figsize=(7, 7))
agriculture, = ax.plot(avg_agriculture['Year'], avg_agriculture['value'], '-')
industry, = ax.plot(avg_industry['Year'], avg_industry['value'], '-')
plt.title("Tỉ lệ công nhân nữ qua các năm")
plt.xlabel("Năm")
plt.ylabel("Tỉ lệ(%)")
ax.legend([agriculture, industry], ['Nông nghiệp', 'Công nghiệp'])
plt.show()

# %% [markdown]
# ## Nhận xét
# Ta thấy rằng tỉ lệ nhân công nữ liên tục giảm qua các năm ở cả 2 nhóm ngành công nghiệp và nông nghiệp và có xu hướng tăng đột biến trong giai đoạn 2021-2022. Dễ dàng thấy được tỉ lệ nhân công nữ ở ngành công nghiệp luôn cao hơn trong nhóm ngành nông nghiệp nhưng cả 2 vẫn chiếm rất thấp (ít hơn 20%). Chính vì thế ta có thể đưa ra kết luận rằng nam giới vẫn là lực lượng lao động chính trong 2 nhóm ngành này khi chiếm tỉ lệ lao động cao hơn hẳn so với nữ giới. Trong tương lai ta có thể đưa ra một số dự đoán như rằng tỉ lệ lao động nữ trong 2 nhóm ngành này sẽ tiếp tục giảm và thay vào đó là tỉ lệ nam giới làm nhóm ngành này tăng lên dẫn đến việc mất cân bằng giới tính trong 2 nhóm ngành kể trên.

# %% [markdown]
# ## Question 4 <br>
# - Phân tích sự tương quan giữa việc sử dụng năng lượng điện và tác động của nó lên GPD
# - Trả lời câu hỏi này ta sẽ rút ra được nền kinh tế châu Âu đang phát triển theo hướng công nghiệp và nông nghiệp (những ngành tiêu thụ nhiều năng lượng) hay phát triển theo hướng những ngành dịch vụ (ít sử dụng năng lượng)/
# - Để trả lời câu hỏi này ta sẽ phân tích mối tương quan giữa mức độ tiêu thụ điện năng qua và phát triển GDP qua từng năm của châu Âu.

# %%
avg_electronic_year = pd.DataFrame()
avg_electronic_year['Avg.Electronic per Year'] = cleaned_df.groupby('Year')['Electric Power Consumption(kWH per capita)'].mean()
avg_electronic_year['Year'] = avg_electronic_year.index
avg_electronic_year.reset_index(inplace=True, drop=True)
avg_electronic_year.head()
# Out:
#    Avg.Electronic per Year  Year
# 0              6100.505402  1995
# 1              6172.027420  1996
# 2              6283.824721  1997
# 3              6445.697604  1998
# 4              6569.394021  1999

# %%
avg_gdp_year = pd.DataFrame()
avg_gdp_year['Avg.GDP per Year'] = cleaned_df.groupby('Year')['GDP in USD'].mean()
avg_gdp_year['Year'] = avg_gdp_year.index
avg_gdp_year.reset_index(inplace=True, drop=True)
avg_gdp_year.head()
# Out:
#    Avg.GDP per Year  Year
# 0      2.856850e+11  1995
# 1      2.909165e+11  1996
# 2      2.759371e+11  1997
# 3      2.735741e+11  1998
# 4      2.629153e+11  1999

# %% [markdown]
# Vì ta chỉ xét sự tăng trưởng của GDP qua các năm chứ không đề cập đến giá trị của nó nên ta sẽ thay đổi lại đơn vị đo cho GDP vì nếu không thay đổi thì giá trị GDP sẽ rất lớn so với lượng tiêu thụ điện năng và sẽ gây khó khăn cho việc trực quan. Ở bài toán này ta sẽ thay đổi đơn vị từ USD sang hundred million USD.

# %%
avg_gdp_year['Avg.GDP per Year'] = avg_gdp_year['Avg.GDP per Year'] / 100000000
avg_gdp_year.head()
# Out:
#    Avg.GDP per Year  Year
# 0       2856.849559  1995
# 1       2909.165151  1996
# 2       2759.370719  1997
# 3       2735.740858  1998
# 4       2629.153013  1999

# %% [markdown]
# ### Trực quan hóa dữ liệu

# %%
fig, (ax1, ax2) = plt.subplots(1,2 ,figsize=(14, 7))
fig.suptitle("Changes in GDP and electric over the years")
fig.supxlabel("Year")
fig.supylabel("Value")
electronic, = ax1.plot(avg_electronic_year['Year'], avg_electronic_year['Avg.Electronic per Year'])
gdp, = ax2.plot(avg_gdp_year['Year'], avg_gdp_year['Avg.GDP per Year'])
ax1.legend([electronic], ['Electronic (kWh)'])
ax2.legend([gdp], ['GDP (hundred million USD)'])

plt.show()

# %% [markdown]
# ### Nhận xét <br>
# Về mặt tổng thể ta có thể thấy tương quan chung giữa việc sử dụng năng lượng điện và mức thu nhập GDP của châu Âu có xu hướng tăng rất mạnh trong giai đoạn 1995 đến 2008 trong đó về mặt GDP có đợt giảm nhẹ trong khoảng 1996 đến 2000. Trong giai đoạn 2008 đến 2022, ta có thể thấy mức xử dụng năng lượng điện có xu hướng đi ngang và giảm mạnh trong khi GDP đi ngang và tăng lên trong giai đoạn 2021 đến 2022. Từ đó ta có thể kết luận về sự chuyển dịch tỉ trọng của nền kinh tế đang từ các ngành tiêu thụ nhiều điện (như các ngành công nghiệp nặng) sang các ngành ít tiêu thụ điện hơn (như phát triển về du lịch, dịch vụ). Điều này có thể dự báo trong tương lai, GDP của châu Âu có xu hướng tăng trưởng nhẹ trong khi mức sử dụng điện có thể tiếp tục giảm. Nói cách khác trong tương lai gần châu Âu có thể dịch chuyển tỉ trọng nền kinh tế từ các ngành tiêu thụ nhiều điện qua các ngành tiêu thụ ít điện và mức tăng GDP sẽ chậm hơn hoặc không đổi.

# %% [markdown]
# ## Question 5
# - Xu hướng chuyển dịch nguồn cung cấp năng lượng, năng lượng hóa thạch và năng lượng tái tạo qua từng năm ở châu Âu
# - Phân tích câu hỏi này ta sẽ trả lời được tình hình sử dụng năng lượng hiện nay ở ở châu Âu, xu hướng chuyển dịch tỉ trọng năng lượng và dự đoán sự dịch chuyển tỉ trọng trong tương lai.
# - Để trả lời câu hỏi này ta sẽ phân tích sự biến động của tỉ lệ đóng góp ở 2 nguồn năng lượng là năng lượng hóa thạch và năng lượng tái tạo qua các năm.

# %%
fossil_fuel_consumption = pd.DataFrame()
fossil_fuel_consumption['Avg.Fossil fuel per Year'] = cleaned_df.groupby('Year')['Fossil Fuel Consumption (%)'].mean()
fossil_fuel_consumption['Year'] = fossil_fuel_consumption.index
fossil_fuel_consumption.reset_index(inplace=True, drop = True)
fossil_fuel_consumption.head(5)
# Out:
#    Avg.Fossil fuel per Year  Year
# 0                 75.643914  1995
# 1                 75.682465  1996
# 2                 75.671436  1997
# 3                 75.784847  1998
# 4                 75.827458  1999

# %%
renewable_energy_consumption = pd.DataFrame()
renewable_energy_consumption['Avg.Renewable energy per Year'] = cleaned_df.groupby('Year')['Renewable Energy Consumption (%)'].mean()
renewable_energy_consumption['Year'] = renewable_energy_consumption.index
renewable_energy_consumption.reset_index(inplace=True, drop = True)
renewable_energy_consumption.head(5)
# Out:
#    Avg.Renewable energy per Year  Year
# 0                      15.657136  1995
# 1                      15.447136  1996
# 2                      15.722386  1997
# 3                      15.747636  1998
# 4                      15.840636  1999

# %%
fig, ax = plt.subplots(figsize = (10, 7))
fossil, = ax.plot(fossil_fuel_consumption['Year'], fossil_fuel_consumption["Avg.Fossil fuel per Year"])
renewable, = ax.plot(renewable_energy_consumption['Year'], renewable_energy_consumption["Avg.Renewable energy per Year"])
fig.suptitle("Probability energy over year")
fig.supxlabel("Year")
fig.supylabel("Probability (%)")
ax.legend([fossil, renewable], ['Fossil Fuel', 'Renewable Energy'])
plt.show()

# %% [markdown]
# ### Nhận xét <br>
# Ta có thể thấy răng tỉ lệ sử dụng năng lượng hóa thạch luôn cao hơn rất nhiều so với tỉ lệ sử dụng năng lượng tái tạo. Lí do có thể do sự tiện dụng và tính ổn định cũng như thói quen sử dụng gây nên. Theo dữ liệu thu được ta có thể đưa ra cái nhìn khái quát đầu tiên trong giai đoạn 1995 đến 2015 mức độ sử dụng năng lượng hóa thạch giảm trong khi mức độ sử dụng năng lượng tái tạo tăng nhẹ. Sự khác biệt đầu tiên xảy ra trong giai đoạn 2015 đến 2020 tỉ lệ sử dụng năng lượng hóa thạch đột nhiên tăng mạnh tại năm 2016 và đi ngang đến hết năm 2020 trong khi tỉ lệ sử dụng năng lượng tái tạo vẫn tiếp tục được ghi nhận tăng ổn định và có phần mạnh hơn một chút so với giai đoạn trước. Từ giai đoạn 2020 đến 2022, ta có thể thấy tỉ lệ sử dụng năng lượng hóa thạch vẫn đi ngang trong khi mức độ sử dụng năng lượng tái tạo sụt giảm mạnh. Điều này có thể đến từ các quốc gia châu Âu thúc đẩy kinh tế trong giai đoạn này (các phân tích ở câu hỏi trước) nên thay vì sử dụng một nguồn năng lượng không ổn định như năng lượng tái tạo thì dịch chuyển mạnh sang năng lượng hóa thạch. Dự đoán trong tương lai gần các quốc gia châu Âu vẫn đang muốn kéo đà tăng trưởng GDP nên có thể tỉ lệ sử dụng năng lượng hóa thạch sẽ được giữ nguyên hoặc có thể tăng nhẹ, trong khi các nguồn năng lượng tái tạo có thể giảm đi do sự bất tiện và tính thiếu hiệu quả nó gây nên.

# %% [markdown]
# ## Question 6
# - Sự đóng góp của ngành nông nghiệp vào tổng GDP quốc gia hiện nay được thể hiện như thế nào?
# - Trả lời được câu hỏi này ta có thể kết luận được giá trị ngành nông nghiệp ở châu Âu và xu hướng phát triển ngành nghề này trong tương lai.
# - Để trả lời được câu hỏi này ta sẽ phân tích tỉ lệ giá trị gia tăng trong nông nghiệp so với tổng GDP của các quốc gia hiện nay.

# %%
value_added = pd.DataFrame()
value_added['Avg.Agriculture value added'] = cleaned_df.groupby('Country')['Agriculture value added(in USD)'].mean()
value_added['Country'] = value_added.index
value_added.reset_index(inplace=True, drop = True)
value_added = value_added.sort_values('Avg.Agriculture value added', ascending=False)
value_added.head(5)
# Out:
#     Avg.Agriculture value added         Country
# 12                 3.921350e+10          France
# 19                 3.826455e+10           Italy
# 35                 3.183010e+10           Spain
# 13                 2.705065e+10         Germany
# 39                 1.679094e+10  United Kingdom

# %%
gdp_country = pd.DataFrame()
gdp_country['Avg.GDP in USD'] = cleaned_df.groupby('Country')['GDP in USD'].mean()
gdp_country["Country"] = gdp_country.index
gdp_country.reset_index(inplace=True, drop=True)

gdp_country.sort_values('Avg.GDP in USD', ascending=False, inplace=True)
gdp_country.head(5)
# Out:
#     Avg.GDP in USD         Country
# 13    3.155095e+12         Germany
# 39    2.414933e+12  United Kingdom
# 12    2.283673e+12          France
# 19    1.802831e+12           Italy
# 35    1.130005e+12           Spain

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))
sns.set(style = "whitegrid")
fig.suptitle("Top 5 country highest agriculture value added and GDP")
ax1.set_title("Average agriculture value added(in USD)")
ax1.set_ylabel("Argiculture value added(in USD)")
ax1.set_xlabel("Country")
ax1.bar(value_added.head(5)['Country'], value_added.head(5)['Avg.Agriculture value added'])

ax2.set_title("Average GDP in USD")
ax2.set_xlabel("Country")
ax2.set_ylabel("GDP in USD")
ax2.bar(gdp_country.head(5)["Country"], gdp_country.head(5)['Avg.GDP in USD'])
plt.show()

# %% [markdown]
# ### Nhận xét <br>
# Theo như biểu đồ, ta nhận xét rằng trong top 5 quốc gia có GDP trung bình cao nhất châu Âu, quốc gia nào có GDP trung bình cao hơn thường có giá trị gia tăng trong ngành nông nghiệp thấp hơn. Điển hình cho nhận định này là nước Đức khi GDP trung bình đứng thứ 1 tại châu Âu nhưng giá trị gia tăng ngành nông nghiệp chỉ đứng thứ 4, sau đó là nước Anh cũng có đặc điểm như vậy khi GDP đứn thứ 2 nhưng đóng góp của ngành nông nghiệp vào GDP chỉ đứng thứ 5. Từ nhận định đó ta có thể kết luận được rằng ngành nông nghiệp không đóng góp nhiều lắm vào GDP quốc gia các nước châu Âu. Thay vào đó các quốc gia này phát triển những ngành mang lại lợi nhuận cao hơn như công nghiệp hoặc dịch vụ. Sau kết luận này ta sẽ xem kĩ hơn tỉ lệ đóng góp của giá trị gia tăng ngành nông nghiệp so với tổng thế GDP quốc gia.

# %%
ratio = pd.DataFrame()
index_sort = value_added.head(5)['Country']

ratio['Country'] = index_sort
ratio['Value'] = value_added.head(5).sort_values('Country')['Avg.Agriculture value added'] / gdp_country.head(5).sort_values('Country')['Avg.GDP in USD'] * 100
ratio.head()
# Out:
#            Country     Value
# 12          France  1.717124
# 19           Italy  2.122470
# 35           Spain  2.816810
# 13         Germany  0.857364
# 39  United Kingdom  0.695296

# %%
fig, ax = plt.subplots(figsize=(7, 5))
fig.suptitle("Percentage of Agriculture value added over GDP in USD")
fig.supxlabel("Country")
fig.supylabel("Probability (%)")
ax.bar(ratio["Country"], ratio["Value"])

plt.show()

# %% [markdown]
# ### Nhận xét <br>
# Theo như đồ thị ta có thể thấy tỉ lệ đóng góp của giá trị gia tăng ngành nông nghiệp vào tổng GDP quốc gia luôn ở mức rất thấp với giá trị cao nhất nằm ở nước Tây Ban Nha chỉ 2.8%. Do đó ta có thể kết luận châu Âu không tập trung phát vào mảng nông nghiệp mà ở các ngành nghề khác. Mặc dù Tây Ban Nha có tỉ trọng ngành nông nghiệp cao nhất nhưng GDP của họ lại thấp nhất trong top 5 cho thấy rằng ngành nông nghiệp này mang lại ít giá trị hơn các ngành khác. Từ đó ta có thể đưa ra dự đoán trong tương lai các nước châu Âu vẫn tiếp tục phát triển ít tập trung ở nhóm ngành nông nghiệp mà sẽ tập trung hơn vào các nhóm ngành khác để đảm bảo đà tăng trưởng GDP.
